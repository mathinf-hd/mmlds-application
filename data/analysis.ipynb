# %% [markdown]
# # Data analysis

# %%
import pandas as pd
import json

# %%
def get_dataframe(filename = "form-data.txt"):
    with open(filename) as f:
        data = json.load(f)
    data_as_flat_list = []
    for topic, topic_data in data.items():
        weight = topic_data["weight"]
        subtopics = topic_data["subtopics"]
        for subtopic, fields in subtopics.items():
            row = fields
            row["Topic"] = topic
            row["Subtopic"] = subtopic
            row["Weight"] = weight
            data_as_flat_list.append(row)
    df = pd.DataFrame(data_as_flat_list).set_index(['Topic', 'Subtopic'])
    df["WeightedCPs"] = df["CPs of lecture"]*df["Weight"]*df["selected"]
    return df

# %%
df = get_dataframe()
df
# Out:
#                                                                                    selected  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming              True
#                                Syntax and semantics of programming languages           True
#                                Abstraction and specialization                          True
#                                Specification and verification of algorithms            True
#                                Termination                                            False
#                                Complexity analysis                                    False
# Technical computer science     Boolean algebra                                         True
#                                Digital circuits                                        True
#                                Sequential logic                                       False
#                                Number representation and encoding                     False
#                                Instruction pipelining                                 False
#                                Branch predictor                                       False
# Algorithms and data structures Fundamentals of algorithms                             False
#                                Run time analysis                                      False
#                                Basic data structures                                  False
#                                Sorting and hashing                                    False
#                                Manipulation of sets                                   False
#                                Search                                                 False
# Operating systems and networks Processes and scheduling                                True
#                                Memory management                                      False
#                                Concurrency and deadlocks                              False
#                                Input/output and files                                 False
#                                OSI model                                              False
#                                Communication and protocols                            False
# Software engineering           Modeling with UML                                      False
#                                Software development process                           False
#                                Requirements engineering                               False
#                                Quality management                                     False
#                                Evolution                                              False
#                                Project management                                     False
# Theoretical computer science   Computability                                          False
#                                Turing machines                                        False
#                                Halting problem                                        False
#                                Finite automaton                                       False
#                                Theory of formal languages                             False
#                                Complexity theory                                      False
# Data bases                     Architecture and functionality of database systems     False
#                                Relational database model                              False
#                                SQL                                                    False
#                                Data integrity                                         False
#                                Physical data organization                             False
#                                Multi-user synchronization                             False
# Linear algebra                 Basics of linear algebra                               False
#                                Vector spaces                                          False
#                                Linear transformations                                 False
#                                Applications of linear transformations                 False
#                                Inner product spaces                                   False
#                                Applications of inner product spaces                   False
# Mathematical analysis          Complex numbers                                         True
#                                Sequences and series                                    True
#                                Continuity, limits, and Taylor expansion                True
#                                Derivatives and mean value theorem                      True
#                                Fundamental theorem of calculus                         True
#                                Integrals and basics of multidimensional analysis       True
#
#                                                                                   Lecture name in transcript  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming                      ASDFASFasdfad
#                                Syntax and semantics of programming languages                        asdasdas
#                                Abstraction and specialization                                           ewgf
#                                Specification and verification of algorithms                         asdasdsd
#                                Termination
#                                Complexity analysis
# Technical computer science     Boolean algebra                                                           asd
#                                Digital circuits                                                          sds
#                                Sequential logic
#                                Number representation and encoding
#                                Instruction pipelining
#                                Branch predictor
# Algorithms and data structures Fundamentals of algorithms
#                                Run time analysis
#                                Basic data structures
#                                Sorting and hashing
#                                Manipulation of sets
#                                Search
# Operating systems and networks Processes and scheduling                                               asdasd
#                                Memory management
#                                Concurrency and deadlocks
#                                Input/output and files
#                                OSI model
#                                Communication and protocols
# Software engineering           Modeling with UML                                                     dsfasdf
#                                Software development process
#                                Requirements engineering
#                                Quality management
#                                Evolution
#                                Project management
# Theoretical computer science   Computability                                                          asdasd
#                                Turing machines
#                                Halting problem
#                                Finite automaton
#                                Theory of formal languages
#                                Complexity theory
# Data bases                     Architecture and functionality of database systems
#                                Relational database model
#                                SQL
#                                Data integrity
#                                Physical data organization
#                                Multi-user synchronization
# Linear algebra                 Basics of linear algebra
#                                Vector spaces
#                                Linear transformations
#                                Applications of linear transformations
#                                Inner product spaces
#                                Applications of inner product spaces
# Mathematical analysis          Complex numbers                                                             a
#                                Sequences and series                                                        b
#                                Continuity, limits, and Taylor expansion                                   cs
#                                Derivatives and mean value theorem                                          a
#                                Fundamental theorem of calculus                                             s
#                                Integrals and basics of multidimensional analysis                          as
#
#                                                                                    CPs of lecture  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming                     0.2
#                                Syntax and semantics of programming languages                  4.0
#                                Abstraction and specialization                                 1.0
#                                Specification and verification of algorithms                   1.0
#                                Termination                                                    0.0
#                                Complexity analysis                                            0.0
# Technical computer science     Boolean algebra                                                2.0
#                                Digital circuits                                               1.0
#                                Sequential logic                                               0.0
#                                Number representation and encoding                             0.0
#                                Instruction pipelining                                         0.0
#                                Branch predictor                                               0.0
# Algorithms and data structures Fundamentals of algorithms                                     0.0
#                                Run time analysis                                              0.0
#                                Basic data structures                                          0.0
#                                Sorting and hashing                                            0.0
#                                Manipulation of sets                                           0.0
#                                Search                                                         0.0
# Operating systems and networks Processes and scheduling                                       0.0
#                                Memory management                                              0.0
#                                Concurrency and deadlocks                                      0.0
#                                Input/output and files                                         0.0
#                                OSI model                                                      0.0
#                                Communication and protocols                                    0.0
# Software engineering           Modeling with UML                                              1.0
#                                Software development process                                   0.0
#                                Requirements engineering                                       0.0
#                                Quality management                                             0.0
#                                Evolution                                                      0.0
#                                Project management                                             0.0
# Theoretical computer science   Computability                                                  1.0
#                                Turing machines                                                0.0
#                                Halting problem                                                0.0
#                                Finite automaton                                               0.0
#                                Theory of formal languages                                     0.0
#                                Complexity theory                                              0.0
# Data bases                     Architecture and functionality of database systems             0.0
#                                Relational database model                                      0.0
#                                SQL                                                            0.0
#                                Data integrity                                                 0.0
#                                Physical data organization                                     0.0
#                                Multi-user synchronization                                     0.0
# Linear algebra                 Basics of linear algebra                                       0.0
#                                Vector spaces                                                  0.0
#                                Linear transformations                                         0.0
#                                Applications of linear transformations                         0.0
#                                Inner product spaces                                           0.0
#                                Applications of inner product spaces                           0.0
# Mathematical analysis          Complex numbers                                                1.0
#                                Sequences and series                                           2.0
#                                Continuity, limits, and Taylor expansion                      10.0
#                                Derivatives and mean value theorem                             2.0
#                                Fundamental theorem of calculus                                3.0
#                                Integrals and basics of multidimensional analysis              1.0
#
#                                                                                    Weight  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming              10
#                                Syntax and semantics of programming languages           10
#                                Abstraction and specialization                          10
#                                Specification and verification of algorithms            10
#                                Termination                                             10
#                                Complexity analysis                                     10
# Technical computer science     Boolean algebra                                          5
#                                Digital circuits                                         5
#                                Sequential logic                                         5
#                                Number representation and encoding                       5
#                                Instruction pipelining                                   5
#                                Branch predictor                                         5
# Algorithms and data structures Fundamentals of algorithms                               2
#                                Run time analysis                                        2
#                                Basic data structures                                    2
#                                Sorting and hashing                                      2
#                                Manipulation of sets                                     2
#                                Search                                                   2
# Operating systems and networks Processes and scheduling                                 3
#                                Memory management                                        3
#                                Concurrency and deadlocks                                3
#                                Input/output and files                                   3
#                                OSI model                                                3
#                                Communication and protocols                              3
# Software engineering           Modeling with UML                                        1
#                                Software development process                             1
#                                Requirements engineering                                 1
#                                Quality management                                       1
#                                Evolution                                                1
#                                Project management                                       1
# Theoretical computer science   Computability                                            1
#                                Turing machines                                          1
#                                Halting problem                                          1
#                                Finite automaton                                         1
#                                Theory of formal languages                               1
#                                Complexity theory                                        1
# Data bases                     Architecture and functionality of database systems       1
#                                Relational database model                                1
#                                SQL                                                      1
#                                Data integrity                                           1
#                                Physical data organization                               1
#                                Multi-user synchronization                               1
# Linear algebra                 Basics of linear algebra                                 1
#                                Vector spaces                                            1
#                                Linear transformations                                   1
#                                Applications of linear transformations                   1
#                                Inner product spaces                                     1
#                                Applications of inner product spaces                     1
# Mathematical analysis          Complex numbers                                          1
#                                Sequences and series                                     1
#                                Continuity, limits, and Taylor expansion                 1
#                                Derivatives and mean value theorem                       1
#                                Fundamental theorem of calculus                          1
#                                Integrals and basics of multidimensional analysis        1
#
#                                                                                    WeightedCPs
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming                  2.0
#                                Syntax and semantics of programming languages              40.0
#                                Abstraction and specialization                             10.0
#                                Specification and verification of algorithms               10.0
#                                Termination                                                 0.0
#                                Complexity analysis                                         0.0
# Technical computer science     Boolean algebra                                            10.0
#                                Digital circuits                                            5.0
#                                Sequential logic                                            0.0
#                                Number representation and encoding                          0.0
#                                Instruction pipelining                                      0.0
#                                Branch predictor                                            0.0
# Algorithms and data structures Fundamentals of algorithms                                  0.0
#                                Run time analysis                                           0.0
#                                Basic data structures                                       0.0
#                                Sorting and hashing                                         0.0
#                                Manipulation of sets                                        0.0
#                                Search                                                      0.0
# Operating systems and networks Processes and scheduling                                    0.0
#                                Memory management                                           0.0
#                                Concurrency and deadlocks                                   0.0
#                                Input/output and files                                      0.0
#                                OSI model                                                   0.0
#                                Communication and protocols                                 0.0
# Software engineering           Modeling with UML                                           0.0
#                                Software development process                                0.0
#                                Requirements engineering                                    0.0
#                                Quality management                                          0.0
#                                Evolution                                                   0.0
#                                Project management                                          0.0
# Theoretical computer science   Computability                                               0.0
#                                Turing machines                                             0.0
#                                Halting problem                                             0.0
#                                Finite automaton                                            0.0
#                                Theory of formal languages                                  0.0
#                                Complexity theory                                           0.0
# Data bases                     Architecture and functionality of database systems          0.0
#                                Relational database model                                   0.0
#                                SQL                                                         0.0
#                                Data integrity                                              0.0
#                                Physical data organization                                  0.0
#                                Multi-user synchronization                                  0.0
# Linear algebra                 Basics of linear algebra                                    0.0
#                                Vector spaces                                               0.0
#                                Linear transformations                                      0.0
#                                Applications of linear transformations                      0.0
#                                Inner product spaces                                        0.0
#                                Applications of inner product spaces                        0.0
# Mathematical analysis          Complex numbers                                             1.0
#                                Sequences and series                                        2.0
#                                Continuity, limits, and Taylor expansion                   10.0
#                                Derivatives and mean value theorem                          2.0
#                                Fundamental theorem of calculus                             3.0
#                                Integrals and basics of multidimensional analysis           1.0

# %%
df[df.selected==True]
# Out:
#                                                                                   selected  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming             True
#                                Syntax and semantics of programming languages          True
#                                Abstraction and specialization                         True
#                                Specification and verification of algorithms           True
# Technical computer science     Boolean algebra                                        True
#                                Digital circuits                                       True
# Operating systems and networks Processes and scheduling                               True
# Mathematical analysis          Complex numbers                                        True
#                                Sequences and series                                   True
#                                Continuity, limits, and Taylor expansion               True
#                                Derivatives and mean value theorem                     True
#                                Fundamental theorem of calculus                        True
#                                Integrals and basics of multidimensional analysis      True
#
#                                                                                  Lecture name in transcript  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming                     ASDFASFasdfad
#                                Syntax and semantics of programming languages                       asdasdas
#                                Abstraction and specialization                                          ewgf
#                                Specification and verification of algorithms                        asdasdsd
# Technical computer science     Boolean algebra                                                          asd
#                                Digital circuits                                                         sds
# Operating systems and networks Processes and scheduling                                              asdasd
# Mathematical analysis          Complex numbers                                                            a
#                                Sequences and series                                                       b
#                                Continuity, limits, and Taylor expansion                                  cs
#                                Derivatives and mean value theorem                                         a
#                                Fundamental theorem of calculus                                            s
#                                Integrals and basics of multidimensional analysis                         as
#
#                                                                                   CPs of lecture  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming                    0.2
#                                Syntax and semantics of programming languages                 4.0
#                                Abstraction and specialization                                1.0
#                                Specification and verification of algorithms                  1.0
# Technical computer science     Boolean algebra                                               2.0
#                                Digital circuits                                              1.0
# Operating systems and networks Processes and scheduling                                      0.0
# Mathematical analysis          Complex numbers                                               1.0
#                                Sequences and series                                          2.0
#                                Continuity, limits, and Taylor expansion                     10.0
#                                Derivatives and mean value theorem                            2.0
#                                Fundamental theorem of calculus                               3.0
#                                Integrals and basics of multidimensional analysis             1.0
#
#                                                                                   Weight  \
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming             10
#                                Syntax and semantics of programming languages          10
#                                Abstraction and specialization                         10
#                                Specification and verification of algorithms           10
# Technical computer science     Boolean algebra                                         5
#                                Digital circuits                                        5
# Operating systems and networks Processes and scheduling                                3
# Mathematical analysis          Complex numbers                                         1
#                                Sequences and series                                    1
#                                Continuity, limits, and Taylor expansion                1
#                                Derivatives and mean value theorem                      1
#                                Fundamental theorem of calculus                         1
#                                Integrals and basics of multidimensional analysis       1
#
#                                                                                   WeightedCPs
# Topic                          Subtopic
# Practical computer science     Technical and formal basics of programming                 2.0
#                                Syntax and semantics of programming languages             40.0
#                                Abstraction and specialization                            10.0
#                                Specification and verification of algorithms              10.0
# Technical computer science     Boolean algebra                                           10.0
#                                Digital circuits                                           5.0
# Operating systems and networks Processes and scheduling                                   0.0
# Mathematical analysis          Complex numbers                                            1.0
#                                Sequences and series                                       2.0
#                                Continuity, limits, and Taylor expansion                  10.0
#                                Derivatives and mean value theorem                         2.0
#                                Fundamental theorem of calculus                            3.0
#                                Integrals and basics of multidimensional analysis          1.0

# %%
df.groupby(level=0)[["selected", "CPs of lecture", "WeightedCPs"]].sum(numeric_only=True)
# Out:
#                                 selected  CPs of lecture  WeightedCPs
# Topic
# Algorithms and data structures         0             0.0          0.0
# Data bases                             0             0.0          0.0
# Linear algebra                         0             0.0          0.0
# Mathematical analysis                  6            19.0         19.0
# Operating systems and networks         1             0.0          0.0
# Practical computer science             4             6.2         62.0
# Software engineering                   0             1.0          0.0
# Technical computer science             2             3.0         15.0
# Theoretical computer science           0             1.0          0.0

# %%
df["WeightedCPs"].sum()
# Out:
# 96.0
